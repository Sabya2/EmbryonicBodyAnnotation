# %%
import pandas as pd
import numpy as np

import dataUtility
import pigeonUtility as pigU

pathToData = '/Users/sabyasachi/Documents/images_v1'
imageList, path = dataUtility.imgMod(pathToData, develop = False,
                                     plotAllSpheroids = False, plotSingleSpheroid = False)
pigU.spheroidAnnotate(path, develop = False)
# Out:
# Created new folder /Users/sabyasachi/Documents/internship_data/code/bigImg_spheroidDetails
# and should have 8 files
# Annotation mode for divided_20230530_JK_BRAF_mc_8_dish_2_d20_230015.tif
# New folder created for divided_20230530_JK_BRAF_mc_8_dish_2_d20_230015.tif
# to save the embryonic body images and annotated csv file
# HTML(value='0 of 45 Examples annotated, Current Position: 0 ')
# ...
# Output()
